# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: object

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
from sklearn.preprocessing import StandardScaler as si
df['Age'] = si().fit_transform(df[['Age']])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex       Age  SibSp  \
# 0                              Kelly, Mr. James    male  0.298549      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  1.181328      1
# 2                     Myles, Mr. Thomas Francis    male  2.240662      0
# 3                              Wirz, Mr. Albert    male -0.231118      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female -0.584229      1
#
#    Parch   Ticket     Fare Cabin Embarked
# 0      0   330911   7.8292   NaN        Q
# 1      0   363272   7.0000   NaN        S
# 2      0   240276   9.6875   NaN        Q
# 3      0   315154   8.6625   NaN        S
# 4      1  3101298  12.2875   NaN        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb  = LabelEncoder()

# %%
df['Cabin'] = lb.fit_transform(df[['Cabin']])
# Out:
# d:\AnacondaNavfile\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex       Age  SibSp  \
# 0                              Kelly, Mr. James    male  0.298549      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  1.181328      1
# 2                     Myles, Mr. Thomas Francis    male  2.240662      0
# 3                              Wirz, Mr. Albert    male -0.231118      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female -0.584229      1
#
#    Parch   Ticket     Fare  Cabin Embarked
# 0      0   330911   7.8292     76        Q
# 1      0   363272   7.0000     76        S
# 2      0   240276   9.6875     76        Q
# 3      0   315154   8.6625     76        S
# 4      1  3101298  12.2875     76        S

# %%
df['Embarked'] = lb.fit_transform(df[['Embarked']])
# Out:
# d:\AnacondaNavfile\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex       Age  SibSp  \
# 0                              Kelly, Mr. James    male  0.298549      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  1.181328      1
# 2                     Myles, Mr. Thomas Francis    male  2.240662      0
# 3                              Wirz, Mr. Albert    male -0.231118      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female -0.584229      1
#
#    Parch   Ticket     Fare  Cabin  Embarked
# 0      0   330911   7.8292     76         1
# 1      0   363272   7.0000     76         2
# 2      0   240276   9.6875     76         1
# 3      0   315154   8.6625     76         2
# 4      1  3101298  12.2875     76         2

# %%
df['Sex'] = lb.fit_transform(df[['Sex']])
# Out:
# d:\AnacondaNavfile\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex       Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  0.298549      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  1.181328      1      0
# 2                     Myles, Mr. Thomas Francis    1  2.240662      0      0
# 3                              Wirz, Mr. Albert    1 -0.231118      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0 -0.584229      1      1
#
#     Ticket     Fare  Cabin  Embarked
# 0   330911   7.8292     76         1
# 1   363272   7.0000     76         2
# 2   240276   9.6875     76         1
# 3   315154   8.6625     76         2
# 4  3101298  12.2875     76         2

# %%
df = df.drop(columns = ['Name'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch   Ticket  \
# 0          892         0       3    1  0.298549      0      0   330911
# 1          893         1       3    0  1.181328      1      0   363272
# 2          894         0       2    1  2.240662      0      0   240276
# 3          895         0       3    1 -0.231118      0      0   315154
# 4          896         1       3    0 -0.584229      1      1  3101298
#
#       Fare  Cabin  Embarked
# 0   7.8292     76         1
# 1   7.0000     76         2
# 2   9.6875     76         1
# 3   8.6625     76         2
# 4  12.2875     76         2

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Cabin           0
# Embarked        0
# dtype: int64
